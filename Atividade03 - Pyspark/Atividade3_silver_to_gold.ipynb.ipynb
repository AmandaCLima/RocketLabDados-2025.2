# %% [markdown]
# # Camada Gold

# %%
# Importação de bibliotecas
from pyspark.sql import functions as F
from pyspark.sql.window import Window
from datetime import timedelta
from pyspark.sql.types import DecimalType

# %%
# Definição do caminho da pasta Gold
catalogo = "medalhao"
gold_db_name = "gold"

# %% [markdown]
# ## 1º Projeto — Área de Logística (Vendas por Localidade)

# %% [markdown]
# ###1.1 Criação da tabela gold.ft_vendas_consumidor_local

# %%
# Leitura das tabelas da silver
ft_pedido_total_silver_df = spark.table("medalhao.silver.ft_pedido_total")
ft_consumidores_silver_df = spark.table("medalhao.silver.ft_consumidores")

# %%
# Checando se cada consumidor possui somente um registro de pedido
display(ft_pedido_total_silver_df.groupBy("id_consumidor").count().orderBy(F.desc("count")).limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_consumidor</th><th>count</th></tr></thead><tbody><tr><td>d3e3cb2b2922f53b23b090d9668a1b13</td><td>1</td></tr><tr><td>3f0bd16414d5fee5cb1d19769c3c825e</td><td>1</td></tr><tr><td>167b9485947ed0a354a3f8dad04eb199</td><td>1</td></tr><tr><td>4d1e62429d88723ea3c9a72fb4c4ffe3</td><td>1</td></tr><tr><td>96d3328d8b8625bc4d656279e1515bee</td><td>1</td></tr></tbody></table></div>

# %%
# Join da tabela ft_pedido_total_silver_df com ft_consumidores_silver_df
ft_vendas_consumidor_local_df = (
    ft_pedido_total_silver_df
    .join(
    ft_consumidores_silver_df,
    on = "id_consumidor",
    how = "inner"
    )
    .select(
    F.col("id_pedido"),
    F.col("id_consumidor"),
    F.col("valor_total_pago_brl").alias("valor_total_pedido_brl").cast(DecimalType(12,2)),
    F.col("cidade"),
    F.col("estado"),
    F.col("data_pedido").cast("date")
    )
)
    
display(ft_vendas_consumidor_local_df.limit(5))

# Salvando a tabela na gold
ft_vendas_consumidor_local_df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable(f"{catalogo}.{gold_db_name}.ft_vendas_consumidor_local")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_pedido</th><th>id_consumidor</th><th>valor_total_pedido_brl</th><th>cidade</th><th>estado</th><th>data_pedido</th></tr></thead><tbody><tr><td>f4471dae8c482f51aa1826cd9f5d4433</td><td>167b9485947ed0a354a3f8dad04eb199</td><td>232.14</td><td>BARUERI</td><td>SP</td><td>2018-07-05</td></tr><tr><td>377627ea55b004e8d55a2af17ba3c0e1</td><td>3f0bd16414d5fee5cb1d19769c3c825e</td><td>207.26</td><td>SAO PAULO</td><td>SP</td><td>2018-05-20</td></tr><tr><td>36da3594f270f9d28bae07df5974d240</td><td>4d1e62429d88723ea3c9a72fb4c4ffe3</td><td>164.54</td><td>QUATIS</td><td>RJ</td><td>2017-10-21</td></tr><tr><td>67009d1f213f762960c97b4f8629159c</td><td>d3e3cb2b2922f53b23b090d9668a1b13</td><td>216.83</td><td>CANARANA</td><td>MT</td><td>2018-01-20</td></tr><tr><td>0ac372f92fbec55ca27ef4fa99a6a13a</td><td>96d3328d8b8625bc4d656279e1515bee</td><td>23.10</td><td>RIO DE JANEIRO</td><td>RJ</td><td>2018-01-11</td></tr></tbody></table></div>

# %% [markdown]
# ###1.2 Criação da view gold.view_total_compras_por_consumidor

# %%
view_total_compras_por_consumidor_df = (
    ft_vendas_consumidor_local_df
    .groupBy("estado", "cidade")
    .agg(
        F.count('*').alias("quantidade_vendas"),
        F.sum("valor_total_pedido_brl").alias("valor_total_localidade")
    )
    .orderBy(F.asc("estado"))
)

display(view_total_compras_por_consumidor_df)

# Salvando a view
view_total_compras_por_consumidor_df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable(f"{catalogo}.{gold_db_name}
# %% [markdown]
# > ##2º Projeto — Área de Logística (Análise de Atrasos de Entregas)

# %% [markdown]
# ### 2.1 Criação da tabela gold.ft_atrasos_pedidos_local_vendedor

# %%
# Leitura das tabelas da silver
ft_pedidos_silver_df = spark.table("medalhao.silver.ft_pedidos")
ft_itens_pedidos_silver_df = spark.table("medalhao.silver.ft_itens_pedidos")

# %%
min_ts = ft_pedidos_silver_df.select(F.min("pedido_compra_timestamp")).collect()[0][0]
max_ts = ft_pedidos_silver_df.select(F.max("pedido_compra_timestamp")).collect()[0][0]

print("Mínimo:", min_ts)
print("Máximo:", max_ts)
# Out:
# Mínimo: 2016-09-04 21:15:19
# Máximo: 2018-10-17 17:30:18

# %%
# Cada pedido está associado a um consumidor, mas um pedido possui vários itens
ft_itens_pedidos_silver_df.groupBy("id_pedido").count().orderBy("count", ascending=False).limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_pedido</th><th>count</th></tr></thead><tbody><tr><td>8272b63d03f5f79c56e9e4120aec44ef</td><td>21</td></tr><tr><td>1b15974a0141d54e36626dca3fdc731a</td><td>20</td></tr><tr><td>ab14fdcfbe524636d65ee38360e22ce8</td><td>20</td></tr><tr><td>428a2f660dc84138d969ccd69a0ab6d5</td><td>15</td></tr><tr><td>9ef13efd6949e4573a18964dd1bbe7f5</td><td>15</td></tr></tbody></table></div>

# %%
# Join da tabela ft_pedidos_silver_df com ft_consumidores_silver_df e ft_itens_pedidos_silver_df
ft_atrasos_pedidos_local_vendedor_df = (
    ft_pedidos_silver_df
    .join(
    ft_consumidores_silver_df,
    on = "id_consumidor",
    how = "inner"
    )
    .join(
    ft_itens_pedidos_silver_df,
    on = "id_pedido",
    how = "inner"
    )
    .select(
    F.col("id_pedido"),
    F.col("id_vendedor"),
    F.col("id_consumidor"),
    F.col("entrega_no_prazo"),
    F.col("tempo_entrega_dias"),
    F.col("tempo_entrega_estimado_dias"),
    F.col("cidade"),
    F.col("estado")
    )
    
)
display(ft_atrasos_pedidos_local_vendedor_df.limit(5))

ft_atrasos_pedidos_local_vendedor_df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable(f"{catalogo}.{gold_db_name}.ft_atrasos_pedidos_local_vendedor")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_pedido</th><th>id_vendedor</th><th>id_consumidor</th><th>entrega_no_prazo</th><th>tempo_entrega_dias</th><th>tempo_entrega_estimado_dias</th><th>cidade</th><th>estado</th></tr></thead><tbody><tr><td>e481f51cbdc54678b7cc49136f2d6af7</td><td>3504c0cb71d7fa48d967e0e4c94d59d9</td><td>9ef432eb6251297304e76186b10a928d</td><td>Sim</td><td>8</td><td>16</td><td>SAO PAULO</td><td>SP</td></tr><tr><td>53cdb2fc8bc7dce0b6741e2150273451</td><td>289cdb325fb7e7f891c38608bf9e0962</td><td>b0830fb4747a6c6d20dea0b8c802d7ef</td><td>Sim</td><td>14</td><td>20</td><td>BARREIRAS</td><td>BA</td></tr><tr><td>47770eb9100c2d0c44946d9cf07ec65d</td><td>4869f7a5dfa277a7dca6462dcf3b52b2</td><td>41ce2a54c0b03bf3443c3d931a367089</td><td>Sim</td><td>9</td><td>27</td><td>VIANOPOLIS</td><td>GO</td></tr><tr><td>949d5b44dbf5de918fe9c16f97b45f8a</td><td>66922902710d126a0e7d26b0e3805106</td><td>f88197465ea7920adcdbec7375364d82</td><td>Sim</td><td>14</td><td>27</td><td>SAO GONCALO DO AMARANTE</td><td>RN</td></tr><tr><td>ad21c59c0840e6cb83a9ceb5573f8159</td><td>2c9e548be18521d1c43cde1c582c6de8</td><td>8ab97904e6daea8866dbdbc4fb7aad2c</td><td>Sim</td><td>3</td><td>13</td><td>SANTO ANDRE</td><td>SP</td></tr></tbody></table></div>

# %% [markdown]
# ###2.2 Criação das Views Analíticas

# %% [markdown]
# ####2.2.1 gold.view_tempo_medio_entrega_localidade

# %%
view_tempo_medio_entrega_localidade_df = (
    ft_atrasos_pedidos_local_vendedor_df
    .groupBy("estado", "cidade")
    .agg(
        # Como o tempo de entrega é em dias, a média deve ser um inteiro
        F.round(F.avg("tempo_entrega_dias"), 0).alias("tempo_medio_entrega"),
        F.round(F.avg("tempo_entrega_estimado_dias"), 0).alias("tempo_medio_estimado"),
    # Se a maioria dos pedidos não atrasa, então NÃO, caso contrário SIM
    F.when(
            F.sum(F.when(F.col("entrega_no_prazo") == "Sim", 1).otherwise(0)) >
            F.sum(F.when(F.col("entrega_no_prazo") == "Não", 1).otherwise(0)),
            "NÃO"
        ).otherwise("SIM").alias("entrega_maior_que_estimado")
    )
    .orderBy(F.asc("estado"), F.asc("cidade"))  
)

display(view_tempo_medio_entrega_localidade_df.limit(10))
view_tempo_medio_entrega_localidade_df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable(f"{catalogo}.{gold_db_name}.view_tempo_medio_entrega_localidade")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>estado</th><th>cidade</th><th>tempo_medio_entrega</th><th>tempo_medio_estimado</th><th>entrega_maior_que_estimado</th></tr></thead><tbody><tr><td>AC</td><td>BRASILEIA</td><td>30.0</td><td>41.0</td><td>NÃO</td></tr><tr><td>AC</td><td>CRUZEIRO DO SUL</td><td>24.0</td><td>57.0</td><td>NÃO</td></tr><tr><td>AC</td><td>EPITACIOLANDIA</td><td>13.0</td><td>44.0</td><td>NÃO</td></tr><tr><td>AC</td><td>MANOEL URBANO</td><td>12.0</td><td>46.0</td><td>NÃO</td></tr><tr><td>AC</td><td>PORTO ACRE</td><td>29.0</td><td>43.0</td><td>NÃO</td></tr><tr><td>AC</td><td>RIO BRANCO</td><td>20.0</td><td>40.0</td><td>NÃO</td></tr><tr><td>AC</td><td>SENADOR GUIOMARD</td><td>14.0</td><td>53.0</td><td>NÃO</td></tr><tr><td>AC</td><td>XAPURI</td><td>25.0</td><td>50.0</td><td>NÃO</td></tr><tr><td>AL</td><td>AGUA BRANCA</td><td>37.0</td><td>38.0</td><td>NÃO</td></tr><tr><td>AL</td><td>ANADIA</td><td>14.0</td><td>35.0</td><td>NÃO</td></tr></tbody></table></div>

# %% [markdown]
# #### 2.2.2 gold.view_vendedor_pontualidade

# %%
view_vendedor_pontualidade_df = (
    ft_atrasos_pedidos_local_vendedor_df
    .groupBy("id_vendedor")
    .agg(
        # Conta pedidos apenas quando o status é diferente de "Não Entregue"
        F.countDistinct(
            F.when(F.col("entrega_no_prazo") != "Não Entregue", F.col("id_pedido"))
        ).alias("total_pedidos_entregues"),
        # Conta todos os pedidos
        F.countDistinct(F.col("id_pedido")).alias("total_pedidos"),
        # Conta atrasados quando entrega_no_prazo == "Não"
        F.sum(F.when(F.col("entrega_no_prazo") == "Não", 1).otherwise(0)).alias("total_atrasados")
    )
    .withColumn(
        "percentual_atraso",
        F.round(F.try_divide(F.col("total_atrasados"), F.col("total_pedidos_entregues")) * 100, 2)
    )
    .drop("total_pedidos_entregues")
)

display(view_vendedor_pontualidade_df.limit(10))

view_vendedor_pontualidade_df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable(f"{catalogo}.{gold_db_name}.view_vendedor_pontualidade")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_vendedor</th><th>total_pedidos</th><th>total_atrasados</th><th>percentual_atraso</th></tr></thead><tbody><tr><td>39a5005f2605cbdb4f9ac14485cabfd1</td><td>3</td><td>0</td><td>0.0</td></tr><tr><td>4e0d109ccfba9a1151c103049880c857</td><td>2</td><td>0</td><td>0.0</td></tr><tr><td>0691148aee60ca47977c187804f935ae</td><td>47</td><td>2</td><td>4.26</td></tr><tr><td>119c7f1a00ef43fad0e57604e76a747c</td><td>2</td><td>0</td><td>0.0</td></tr><tr><td>fa14641f57b655e933124a9ea49cd7a5</td><td>7</td><td>0</td><td>0.0</td></tr><tr><td>3d4824f20035949c710eaf111f869d39</td><td>9</td><td>2</td><td>25.0</td></tr><tr><td>87d3c3aeb3ead335511b3ce315eb341e</td><td>15</td><td>1</td><td>6.67</td></tr><tr><td>3364a91ec4d56c98e44174de954b94f6</td><td>6</td><td>0</td><td>0.0</td></tr><tr><td>a13580f0e8f782b7a543885a0ef99f08</td><td>10</td><td>2</td><td>20.0</td></tr><tr><td>fb3cfbc8a86f5d7fbb4d36b8df63f60d</td><td>10</td><td>0</td><td>0.0</td></tr></tbody></table></div>

# %% [markdown]
# ## 3º Projeto — Área Comercial (Análises de Vendas por Período)

# %% [markdown]
# ### 3.1 Criação da Dimensão de Tempo — gold.dm_tempo

# %%
# mesma data definida para cotação
data_inicio = "2016-09-03"
data_fim = "2018-10-16"

# %%
dicionario_mes = {
    "January": "Janeiro",
    "February": "Fevereiro",
    "March": "Março",
    "April": "Abril",
    "May": "Maio",
    "June": "Junho",
    "July": "Julho",
    "August": "Agosto",
    "September": "Setembro",
    "October": "Outubro",
    "November": "Novembro",
    "December": "Dezembro"
}

dicionario_semana = {
    "Monday": "Segunda",
    "Tuesday": "Terça",
    "Wednesday": "Quarta",
    "Thursday": "Quinta",
    "Friday": "Sexta",
    "Saturday": "Sábado",
    "Sunday": "Domingo"
}

# Cria o mapeamento para português
mapa_meses = F.create_map([F.lit(x) for x in sum(dicionario_mes.items(), ())])
mapa_semana = F.create_map([F.lit(x) for x in sum(dicionario_semana.items(), ())])

# %%
dm_tempo_df = (
    spark.sql("SELECT sequence(to_date('{0}'), to_date('{1}'), interval 1 day) AS datas"
              .format(data_inicio, data_fim))
    .withColumn("sk_tempo", F.explode("datas"))
    .drop("datas")
    .withColumn("ano", F.year("sk_tempo"))
    .withColumn("trimestre", F.quarter("sk_tempo"))
td><td>2016</td><td>3</td><td>9</td><td>38</td><td>21</td><td>4</td><td>Setembro</td><td>Quarta</td><td>Não</td></tr><tr><td>2016-09-22</td><td>2016</td><td>3</td><td>9</td><td>38</td><td>22</td><td>5</td><td>Setembro</td><td>Quinta</td><td>Não</td></tr><tr><td>2016-09-23</td><td>2016</td><td>3</td><td>9</td><td>38</td><td>23</td><td>6</td><td>Setembro</td><td>Sexta</td><td>Não</td></tr><tr><td>2016-09-24</td><td>2016</td><td>3</td><td>9</td><td>38</td><td>24</td><td>7</td><td>Setembro</td><td>Sábado</td><td>Sim</td></tr><tr><td>2016-09-25</td><td>2016</td><td>3</td><td>9</td><td>38</td><td>25</td><td>1</td><td>Setembro</td><td>Domingo</td><td>Sim</td></tr><tr><td>2016-09-26</td><td>2016</td><td>3</td><td>9</td><td>39</td><td>26</td><td>2</td><td>Setembro</td><td>Segunda</td><td>Não</td></tr><tr><td>2016-09-27</td><td>2016</td><td>3</td><td>9</td><td>39</td><td>27</td><td>3</td><td>Setembro</td><td>Terça</td><td>Não</td></tr><tr><td>2016-09-28</td><td>2016</td><td>3</td><td>9</td><td>39</td><td>28</td><td>4</td><td>Setembro</td><td>Quarta</td><td>Não</td></tr><tr><td>2016-09-29</td><td>2016</td><td>3</td><td>9</td><td>39</td><td>29</td><td>5</td><td>Setembro</td><td>Quinta</td>< ...

# %% [markdown]
# ### 3.2 Criação da Fato gold.ft_vendas_geral

# %%
ft_produtos_silver_df = spark.table("medalhao.silver.ft_produtos")
ft_avaliacoes_pedidos_silver_df = spark.table("medalhao.silver.ft_avaliacoes_pedidos")
dm_cotacao_dolar_silver_df = spark.table("medalhao.silver.dm_cotacao_dolar")

# %%
# Transformação dos tipos
dm_cotacao_dolar_silver_df = (
    dm_cotacao_dolar_silver_df
        .withColumn("data", F.to_date("data"))
        .withColumn("cotacao_dolar", F.col("cotacao_dolar").cast(DecimalType(8,4)))
)

# %%
ft_vendas_geral_df = (
    ft_pedidos_silver_df
        .join(ft_avaliacoes_pedidos_silver_df, "id_pedido", "left")
        .join(ft_itens_pedidos_silver_df, "id_pedido", "left")
        .join(ft_produtos_silver_df, "id_produto", "left")
        .join(
            dm_cotacao_dolar_silver_df,
            F.to_date("pedido_compra_timestamp") == F.col("data"),
            "left"
        )


        .select(
            # IDs e FKs
            F.col("id_pedido"),
            F.col("id_item"),
            F.col("id_consumidor").alias("fk_cliente"),
            F.col("id_produto").alias("fk_produto"),
            F.col("id_vendedor").alias("fk_vendedor"),
            F.to_date("pedido_compra_timestamp").alias("fk_tempo"),

            F.col("status").alias("status_pedido"),
            F.col("tempo_entrega_dias"),
            F.col("entrega_no_prazo"),

            # Valores BRL 
            F.col("preco_BRL").alias("valor_produto_brl").cast(DecimalType(12, 2)),
            F.col("preco_frete").alias("valor_frete_brl").cast(DecimalType(12, 2)),
            (
                (F.col("preco_BRL") + F.col("preco_frete"))
                .cast(DecimalType(12, 2))
            ).alias("valor_total_item_brl"),

            # Conversão para USD com proteção contra divisão por zero e nulo
            (
                F.when(F.col("cotacao_dolar").isNull(), None)
                 .when(F.col("cotacao_dolar") == 0, None)   # evita crash
                 .otherwise(F.col("preco_BRL") / F.col("cotacao_dolar"))
            ).cast(DecimalType(12,2)).alias("valor_produto_usd"),

            (
                F.when(F.col("cotacao_dolar").isNull(), None)
                 .when(F.col("cotacao_dolar") == 0, None)
                 .otherwise(F.col("preco_frete") / F.col("cotacao_dolar"))
            ).cast(DecimalType(12,2)).alias("valor_frete_usd"),

            (
                F.when(F.col("cotacao_dolar").isNull(), None)
                 .when(F.col("cotacao_dolar") == 0, None)
                 .otherwise(
                    (F.col("preco_BRL") + F.col("preco_frete")) /
                     F.col("cotacao_dolar")
                 )
            ).cast(DecimalType(12,2)).alias("valor_total_item_usd"),

            F.col("cotacao_dolar"),

            # Avaliação 
            F.col("avaliacao")
                .cast(DecimalType(3,2))
                .alias("avaliacao_pedido")
        )
)


# Preview no Databricks
display(ft_vendas_geral_df.limit(10))

ft_vendas_geral_df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable(f"{catalogo}.{gold_db_name}.ft_vendas_geral")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_pedido</th><th>id_item</th><th>fk_cliente</th><th>fk_produto</th><th>fk_vendedor</th><th>fk_tempo</th><th>status_pedido</th><th>tempo_entrega_dias</th><th>entrega_no_prazo</th><th>valor_produto_brl</th><th>valor_frete_brl</th><th>valor_total_item_brl</th><th>valor_produto_usd</th><th>valor_frete_usd</th><th>valor_total_item_usd</th><th>cotacao_dolar</th><th>avaliacao_pedido</th></tr></thead><tbody><tr><td>e481f51cbdc54678b7cc49136f2d6af7</td><td>1</td><td>9ef432eb6251297304e76186b10a928d</td><td>87285b34884572647811a353c7ac498a</td><td>3504c0cb71d7fa48d967e0e4c94d59d9</td><td>2017-10-02</td><td>entregue</td><td>8</td><td>Sim</td><td>29.99</td><td>8.72</td><td>38.71</td><td>9.48</td><td>2.76</td><td>12.24</td><td>3.1636</td><td>4.00</td></tr><tr><td>53cdb2fc8bc7dce0b6741e2150273451</td><td>1</td><td>b0830fb4747a6c6d20dea0b8c802d7ef</td><td>595fac2a385ac33a80bd5114aec74eb8</td><td>289cdb325fb7e7f891c38608bf9e0962</td><td>2018-07-24</td><td>entregue</td><td>14</td><td>Sim</td><td>118.70</td><td>22.76</td><td>141.46</td><td>31.69</td><td>6.08</td><td>37.77</td><td>3.7453</td><td>4.00</td></tr><tr><td>47770eb9100c2d0c44946d9cf07ec65d</td><td>1</td><td>41ce2a54c0b03bf3443c3d931a367089</td><td>aa4383b373c6aca5d8797843e5594415</td><td>4869f7a5dfa277a7dca6462dcf3b52b2</td><td>2018-08-08</td><td>entregue</td><td>9</td><td>Sim</td><td>159.90</td><td>19.22</td><td>179.12</td><td>42.63</td><td>5.12</td><td>47.75</td><td>3.7513</td><td>5.00</td></tr><tr><td>949d5b44dbf5de918fe9c16f97b45f8a</td><td>1</td><td>f88197465ea7920adcdbec7375364d82</td><td>d0b61bfb1de832b15ba9d266ca96e5b0</td><td>66922902710d126a0e7d26b0e3805106</td><td>2017-11-18</td><td>entregue</td><td>14</td><td>Sim</td><td>45.00</td><td>27.20</td><td>72.20</td><td>13.73</td><td>8.30</td><td>22.02</td><td>3.2782</td><td>5.00</td></tr><tr><td>ad21c59c0840e6cb83a9ceb5573f8159</td><td>1</td><td>8ab97904e6daea8866dbdbc4fb7aad2c</td><td>65266b2da20d04dbe00c5c2d3bb7859e</td><td>2c9e548be18521d1c43cde1c582c6de8</td><td>2018-02-13</td><td>entregue</td><td>3</td><td>Sim</td><td>19.90</td><td>8.72</td><td>28.62</td><td>null</td><td>null</td><td>null</td><td>null</td><td>5.00</td></tr><tr><td>a4591c265e18cb1dcee52889e2d8acc3</td><td>1</td><td>503740e9ca751ccdda7ba28e9ab8f608</td><td>060cb19345d90064d1015407193c233d</td><td>8581055ce74af1daba164fdbd55a40de</td><td>2017-07-09</td><td>entregue</td><td>17</td><td>Sim</td><td>147.90</td><td>27.36</td><td>175.26</td><td>44.97</td><td>8.32</td><td>53.29</td><td>3.2889</td><td>4.00</td></tr><tr><td>136cce7faa42fdb2cefd53fdc79a6098</td><td>1</td><td>ed0271e0b7da060a393796590e7b737a</td><td>a1804276d9941ac0733cfd409f5206eb</td><td>dc8798cbf453b7e0f98745e396cc5616</td><td>2017-04-11</td><td>faturado</td><td>null</td><td>Não Entregue</td><td>49.90</td><td>16.05</td><td>65.95</td><td>15.88</td><td>5.11</td><td>20.99</td><td>3.1418</td><td>2.00</td></tr><tr><td>6514b8ad8028c9f2cc2374ded245783f</td><td>1</td><td>9bdf08b4b3b52b5526ff42d37d47f222</td><td>4520766ec412348b8d4caa5e8a18c464</td><td>16090f2ca825584b5a147ab24aa30c86</td><td>2017-05-16</td><td>entregue</td><td>10</td><td>Sim</td><td>59.99</td><td>15.17</td><td>75.16</td><td>19.40</td><td>4.91</td><td>24.31</td><td>3.0918</td><td>5.00</td></tr><tr><td>76c6e866289321a7c93b82b54852dc33</td><td>1</td><td>f54a9f0e6b351c431402b8461ea51999</td><td>ac1789e492dcd698c5c10b97a671243a</td><td>63b9ae557efed31d1f7687917d248a8d</td><td>2017-01-23</td><td>entregue</td><td>10</td><td>Sim</td><td>19.90</td><td>16.05</td><td>35.95</td><td>6.30</td><td>5.08</td><td>11.38</td><td>3.1603</td><td>1.00</td></tr><tr><td>e69bfb5eb88e0ed6a785585b27e16dbf</td><td>1</td><td>31ad1d1b63eb9962463f764d4e6e0c9d</td><td>9a78fb9862b10749a117f7fc3c31f051</td><td>7c67e1448b00f6e969d365cea6b010ab</td><td>2017-07-29</td><td>entregue</td><td>18</td><td>Sim</td><td>149.99</td><td>19.77</td><td>169.76</td><td>47.69</td ...

# %% [markdown]
# ### 3.3 Criação da view gold.view_vendas_por_periodo

# %%
view_vendas_por_periodo_df = ( 
    ft_vendas_geral_df
    .join(dm_tempo_df, F.col("fk_tempo") == F.col("sk_tempo"), "inner")
    .groupBy(
        "ano",
        "trimestre",
        "mes",
        "dia_da_semana_num"
    )
    .agg(
        F.countDistinct("id_pedido").alias("total_pedidos").cast("bigint"),
        F.count("id_item").alias("total_itens").cast("bigint"),
        # Soma do valor total de vendas em reais
        # Lembrando que o valor total inclui o frete
        F.sum("valor_total_item_brl").cast(DecimalType(12,2)).alias("receita_total_brl"),
        F.sum("valor_total_item_usd").cast(DecimalType(12,2)).alias("receita_total_usd"),
        F.avg("valor_total_item_brl").cast(DecimalType(12,2)).alias("ticket_medio_brl"),
        F.avg("avaliacao_pedido").cast(DecimalType(3,2)).alias("avaliacao_media")
    )
    # Para obter o nome do mês e o dia 
    .join(
td></tr></tbody></table></div>

# %% [markdown]
# #### 3.3.1 Consultas Analíticas

# %%
# %sql
SELECT 
    case    
        when dia_da_semana_num = 1 then 'Domingo' 
        when dia_da_semana_num = 2 then 'Segunda-feira' 
        when dia_da_semana_num = 3 then 'Terça-feira' 
        when dia_da_semana_num = 4 then 'Quarta-feira' 
        when dia_da_semana_num = 5 then 'Quinta-feira' 
        when dia_da_semana_num = 6 then 'Sexta-feira' 
        when dia_da_semana_num = 7 then 'Sábado' 
    end AS dia_da_semana_nome,
    SUM(receita_total_brl) AS receita_total
FROM medalhao.gold.view_vendas_por_periodo
GROUP BY dia_da_semana_nome
ORDER BY receita_total DESC
LIMIT 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dia_da_semana_nome</th><th>receita_total</th></tr></thead><tbody><tr><td>Segunda-feira</td><td>11429627.14</td></tr></tbody></table></div>

# %%
# %sql
-- Retorna dados do último ano
WITH ultimo_ano AS (
    SELECT *
    FROM  medalhao.gold.view_vendas_por_periodo
    WHERE ano = (
        SELECT MAX(ano)
        FROM medalhao.gold.view_vendas_por_periodo
    )
)

SELECT 
    ano,
    mes,
    mes_nome,
    AVG(ticket_medio_brl) AS ticket_medio
FROM ultimo_ano
GROUP BY ano, mes, mes_nome
ORDER BY ticket_medio DESC
LIMIT 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ano</th><th>mes</th><th>mes_nome</th><th>ticket_medio</th></tr></thead><tbody><tr><td>2018</td><td>9</td><td>Setembro</td><td>166.460000</td></tr></tbody></table></div>

# %% [markdown]
# ### 3.4. Criação da gold.view_top_produto

# %%
view_top_produto_df = (
    ft_vendas_geral_df
    .join(ft_produtos_silver_df, F.col("fk_produto") == F.col("id_produto"), "inner")
    .groupBy('id_produto', 'categoria_produto')
    .agg(
        F.count('id_item').alias("quantidade_vendida").cast("bigint"),
        F.countDistinct("id_pedido").alias("total_pedidos").cast("bigint"),
        F.sum('valor_produto_brl').alias('receita_brl').cast(DecimalType(12,2)),
        F.sum('valor_produto_usd').alias('receita_usd').cast(DecimalType(12,2)),
        F.avg('valor_produto_brl').alias('preco_medio_brl').cast(DecimalType(12,2)),
        F.avg('avaliacao_pedido').alias('avaliacao_media').cast(DecimalType(3,2)),
        F.avg("peso_produto_gramas").alias("peso_medio_gramas").cast(DecimalType(8,2))
    )
)
    

display(view_top_produto_df.limit(5))
view_top_produto_df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable(f"{catalogo}.{gold_db_name}.view_top_produto")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_produto</th><th>categoria_produto</th><th>quantidade_vendida</th><th>total_pedidos</th><th>receita_brl</th><th>receita_usd</th><th>preco_medio_brl</th><th>avaliacao_media</th><th>peso_medio_gramas</th></tr></thead><tbody><tr><td>2b4609f8948be18874494203496bc318</td><td>beleza_saude</td><td>269</td><td>259</td><td>23527.13</td><td>7007.56</td><td>87.46</td><td>4.07</td><td>250.00</td></tr><tr><td>54f45413afc0d5480c59f5dfeed2d19f</td><td>beleza_saude</td><td>9</td><td>7</td><td>1199.10</td><td>348.61</td><td>133.23</td><td>4.00</td><td>2450.00</td></tr><tr><td>34beebdf2b189075548689f23441ad50</td><td>informatica_acessorios</td><td>2</td><td>2</td><td>1383.30</td><td>428.70</td><td>691.65</td><td>3.50</td><td>2717.00</td></tr><tr><td>2c4930c4b284c7b99db2a4c52071a45e</td><td>moveis_decoracao</td><td>9</td><td>3</td><td>405.00</td><td>118.44</td><td>45.00</td><td>2.78</td><td>9050.00</td></tr><tr><td>675eadffd43ac06d1bead694fb553d35</td><td>moveis_decoracao</td><td>1</td><td>1</td><td>109.90</td><td>35.30</td><td>109.90</td><td>5.00</td><td>2000.00</td></tr></tbody></table></div>

# %% [markdown]
# ###3.5 Criação da view_vendas_produtos_esteticos

# %%
display(
    ft_produtos_silver_df.groupBy("categoria_produto").count().where(ft_produtos_silver_df.categoria_produto.like('fashion%'))
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>categoria_produto</th><th>count</th></tr></thead><tbody><tr><td>fashion_calcados</td><td>173</td></tr><tr><td>fashion_bolsas_e_acessorios</td><td>849</td></tr><tr><td>fashion_underwear_e_moda_praia</td><td>53</td></tr><tr><td>fashion_roupa_masculina</td><td>95</td></tr><tr><td>fashion_roupa_feminina</td><td>27</td></tr><tr><td>fashion_esporte</td><td>19</td></tr><tr><td>fashion_roupa_infanto_juvenil</td><td>5</td></tr></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE TABLE medalhao.gold.view_fashion_performance AS
WITH vendas_fashion AS (
    SELECT
        t.ano,
        t.mes,
        p.categoria_produto,
        f.id_pedido,
        f.id_item,
        f.valor_produto_brl,
        f.valor_produto_usd,
        f.avaliacao_pedido
    FROM medalhao.gold.ft_vendas_geral f
    JOIN medalhao.gold.dm_tempo t ON f.fk_tempo = t.sk_tempo
    JOIN medalhao.silver.ft_produtos p ON f.fk_produto = p.id_produto
    WHERE p.categoria_produto LIKE 'fashion%'
)

SELECT
    ano,
    mes,
    categoria_produto,

    -- Contando total_pedidos e total_itens_vendidos
    CAST(COUNT(DISTINCT id_pedido) AS BIGINT) AS total_pedidos,
    CAST(COUNT(id_item) AS BIGINT) AS total_itens_vendidos,

    -- Calculando receitas
    CAST(SUM(valor_produto_brl) AS DECIMAL(12,2)) AS receita_total_brl,
    CAST(SUM(valor_produto_usd) AS DECIMAL(12,2)) AS receita_total_usd,

    CAST(AVG(valor_produto_brl) AS DECIMAL(12,2)) AS ticket_medio_brl,
    CAST(AVG(valor_produto_usd) AS DECIMAL(12,2)) AS ticket_medio_usd,
    CAST(AVG(avaliacao_pedido) AS DECIMAL(3,2)) AS avaliacao_media

FROM vendas_fashion
GROUP BY ano, mes, categoria_produto
-- Ordenando para facilitar a visualização
ORDER BY ano, mes, categoria_produto;

-- Visualizando a view criada
SELECT * FROM medalhao.gold.view_fashion_performance LIMIT 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ano</th><th>mes</th><th>categoria_produto</th><th>total_pedidos</th><th>total_itens_vendidos</th><th>receita_total_brl</th><th>receita_total_usd</th><th>ticket_medio_brl</th><th>ticket_medio_usd</th><th>avaliacao_media</th></tr></thead><tbody><tr><td>2016</td><td>10</td><td>fashion_bolsas_e_acessorios</td><td>8</td><td>9</td><td>508.30</td><td>157.94</td><td>56.48</td><td>17.55</td><td>3.22</td></tr><tr><td>2016</td><td>10</td><td>fashion_calcados</td><td>1</td><td>1</td><td>29.99</td><td>9.28</td><td>29.99</td><td>9.28</td><td>5.00</td></tr><tr><td>2016</td><td>10</td><td>fashion_roupa_feminina</td><td>1</td><td>1</td><td>54.90</td><td>16.97</td><td>54.90</td><td>16.97</td><td>5.00</td></tr><tr><td>2016</td><td>10</td><td>fashion_roupa_masculina</td><td>1</td><td>1</td><td>24.90</td><td>7.70</td><td>24.90</td><td>7.70</td><td>1.00</td></tr><tr><td>2016</td><td>12</td><td>fashion_bolsas_e_acessorios</td><td>1</td><td>1</td><td>10.90</td><td>3.33</td><td>10.90</td><td>3.33</td><td>5.00</td></tr></tbody></table></div>
